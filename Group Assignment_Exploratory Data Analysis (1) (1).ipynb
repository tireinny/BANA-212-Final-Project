# %% [markdown]
# # Group Assignment. Exploratory Data Analysis
#
# In this assignment, we will focus on exploratory data analysis of stock prices. Keep in mind, this assignment is just meant to practice your pandas skills, it is not meant to be a robust financial analysis or be taken as financial advice.
# ____
# ** NOTE: This project is challenging and you have to look things up on your own to try to solve the tasks issued. **
# ____
# We'll focus on tech stocks and see how they progressed in the year of 2023. You may look at other sectors as well in the end of this notebook, such as Airline companies and retail industry.
#
# To submit the assignment you can download the completed assignment in the **.ipynb** format **as well as** the **.pdf** from the notebook (go to File->Download as) and upload the same on Canvas. If someone is not able to upload the file in .ipynb format or .pdf, please upload the .html version.

# %% [markdown]
# # Part 1
#
#
# ## Get the Data
#
# In this section we will learn how to use pandas to directly read data from Yahoo! Finance's API.
#
# First we need to start with the proper imports, which we've already laid out for you here.
#
# *Note: [You'll need to install yfinance for this to work!](https://github.com/ranaroussi/yfinance) Use this link for install guidance (**pip install yfinance**).*
#
# ### The Imports
#
# You need to install pandas yfinance first. You may comment out the first line in the following cell to install the module or use the command line and run the following command:
#
# python3 -m pip install yfinance
#
# The -m tells it to install the module.

# %%
# !pip install yfinance
import yfinance as yf
# Out:
# Requirement already satisfied: yfinance in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.3.0)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.3.0)
# Requirement already satisfied: requests>=2.31 in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\tuong\appdata\roaming\python\python311\site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (6.33.0)
# Requirement already satisfied: websockets>=13.0 in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.10.5)
# Requirement already satisfied: pycparser in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tuong\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.31->yfinance) (2.5.0)

# %%
import pandas as pd
import numpy as np
pd.core.common.is_list_like = pd.api.types.is_list_like

import datetime
# %matplotlib inline

# %% [markdown]
# ## Data
#
# We need to get data using Yahoo Finance API. We will get stock information for the following companies:
# * Amazon
# * Meta
# * Alphabet
# * Microsoft
# * Apple
#
#
# Figure out how to get the stock data from Jan. 1st 2023 to Dec. 31st 2023 for each of these companies. Set each company to be a separate dataframe, with the variable name for that company being its ticker symbol. This will involve a few steps:
# 1. Use datetime to set start and end datetime objects.
# 2. Figure out the ticker symbol for each company.
# 2. Figure out how to use datareader to grab info on the stock.
#
# Use [this documentation page](https://pypi.org/project/yfinance/) for hints and instructions

# %%
start = datetime.datetime(2023, 1, 1)
end = datetime.datetime(2023, 12, 31)

# %%
# Amazon
Amazon = yf.download("AMZN", start, end)

# Meta
Meta = yf.download("META", start, end)

# Alphabet
Alphabet = yf.download("GOOG", start, end)

# Microsoft
Microsoft = yf.download("MSFT", start, end)

# Apple
Apple = yf.download("AAPL", start, end)
# Out:
# C:\Users\Tuong\AppData\Local\Temp\ipykernel_21796\3984462399.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   Amazon = yf.download("AMZN", start, end)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Tuong\AppData\Local\Temp\ipykernel_21796\3984462399.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   Meta = yf.download("META", start, end)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Tuong\AppData\Local\Temp\ipykernel_21796\3984462399.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   Alphabet = yf.download("GOOG", start, end)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Tuong\AppData\Local\Temp\ipykernel_21796\3984462399.py:11: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   Microsoft = yf.download("MSFT", start, end)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Tuong\AppData\Local\Temp\ipykernel_21796\3984462399.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   Apple = yf.download("AAPL", start, end)
# [*********************100%***********************]  1 of 1 completed

# %%
Amazon.reset_index(inplace=True)
Meta.reset_index(inplace=True)
Alphabet.reset_index(inplace=True)
Microsoft.reset_index(inplace=True)
Apple.reset_index(inplace=True)

# %%
Amazon.head()
# Out:
# Price        Date      Close       High        Low       Open    Volume
# Ticker                  AMZN       AMZN       AMZN       AMZN      AMZN
# 0      2023-01-03  85.820000  86.959999  84.209999  85.459999  76706000
# 1      2023-01-04  85.139999  86.980003  83.360001  86.550003  68885100
# 2      2023-01-05  83.120003  85.419998  83.070000  85.330002  67930800
# 3      2023-01-06  86.080002  86.400002  81.430000  83.029999  83303400
# 4      2023-01-09  87.360001  89.480003  87.080002  87.459999  65266100

# %% [markdown]
# ##### Add a Column_Company Name (this is filled out for you)

# %%
Amazon["Company"]='Amazon'
Meta["Company"]='Meta'
Microsoft["Company"]='Microsoft'
Apple["Company"]='Apple'
Alphabet["Company"]='Alphabet'

# %% [markdown]
# #### Alternatively
#
# You may download the datasets from Canvas and then import them in this notebook.

# %%
Amazon = pd.read_csv("Amazon.csv")

Meta = pd.read_csv("Meta.csv")

Microsoft = pd.read_csv("Microsoft.csv")

Apple = pd.read_csv("Apple.csv")

Alphabet = pd.read_csv("Alphabet.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 Amazon = pd.read_csv("Amazon.csv")
#       3 Meta = pd.read_csv("Meta.csv")
#       5 Microsoft = pd.read_csv("Microsoft.csv")
#
# File c:\Users\Tuong\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Tuong\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\Tuong\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Tuong\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\Tuong\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Amazon.csv'

# %% [markdown]
# ##### Append all the data sets - these five tables

# %%
# your code here

prices=Amazon.copy()

prices=pd.merge(prices,Microsoft,how='inner',on='Date',suffixes=('_AMZN','_MSFT'))
prices=pd.merge(prices,Meta,how='inner',on='Date',suffixes=('_MSFT','_META'))
prices=pd.merge(prices,Alphabet,how='inner',on='Date',suffixes=('_META','_GOOG'))
prices=pd.merge(prices,Apple,how='inner',on='Date',suffixes=('_META','_GOOG'))

prices.head()
# Out:
# C:\Users\Tuong\AppData\Local\Temp\ipykernel_21796\175693666.py:5: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   prices=pd.merge(prices,Microsoft,how='inner',on='Date',suffixes=('_AMZN','_MSFT'))
# C:\Users\Tuong\AppData\Local\Temp\ipykernel_21796\175693666.py:6: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   prices=pd.merge(prices,Meta,how='inner',on='Date',suffixes=('_MSFT','_META'))
# C:\Users\Tuong\AppData\Local\Temp\ipykernel_21796\175693666.py:7: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   prices=pd.merge(prices,Alphabet,how='inner',on='Date',suffixes=('_META','_GOOG'))
# C:\Users\Tuong\AppData\Local\Temp\ipykernel_21796\175693666.py:8: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   prices=pd.merge(prices,Apple,how='inner',on='Date',suffixes=('_META','_GOOG'))
# Price        Date      Close       High        Low       Open    Volume  \
# Ticker                  AMZN       AMZN       AMZN       AMZN      AMZN
# 0      2023-01-03  85.820000  86.959999  84.209999  85.459999  76706000
# 1      2023-01-04  85.139999  86.980003  83.360001  86.550003  68885100
# 2      2023-01-05  83.120003  85.419998  83.070000  85.330002  67930800
# 3      2023-01-06  86.080002  86.400002  81.430000  83.029999  83303400
# 4      2023-01-09  87.360001  89.480003  87.080002  87.459999  65266100
#
# Price  Company_AMZN       Close        High         Low  ...             \
# Ticker                     MSFT        MSFT        MSFT  ...       GOOG
# 0            Amazon  234.423569  240.460771  232.290481  ...  88.414953
# 1            Amazon  224.169144  227.857992  221.096726  ...  87.203260
# 2            Amazon  217.525269  222.652495  216.987103  ...  85.971673
# 3            Amazon  220.088882  220.901020  214.628992  ...  84.988398
# 4            Amazon  222.231766  226.263102  221.537055  ...  87.977943
#
# Price        Open    Volume Company_GOOG       Close        High         Low  \
# Ticker       GOOG      GOOG                     AAPL        AAPL        AAPL
# 0       89.219453  20738500     Alphabet  123.330650  129.079567  122.443165
# 1       90.391442  27046500     Alphabet  124.602707  126.870724  123.340509
# 2       87.471412  23136100     Alphabet  123.281342  125.993097  123.024963
# 3       86.766233  26612600     Alphabet  127.817352  128.478033  123.153137
# 4       88.588761  22996700     Alphabet  128.340012  131.554685  128.083633
#
# Price         Open     Volume Company
# Ticker        AAPL       AAPL
# 0       128.468194  112117500   Apple
# 1       125.125335   89113600   Apple
# 2       125.361998   80962700   Apple
# 3       124.257564   87754700   Apple
# 4       128.655569   70790800   Apple
#
# [5 rows x 31 columns]

# %% [markdown]
# ##### Derive the average closing price for each company

# %%
# your code here
avg_cost=prices['Close'].mean()
print(avg_cost)
# Out:
# Ticker
# AMZN    121.372800
# MSFT    308.715736
# META    259.822548
# GOOG    118.798889
# AAPL    170.676109
# dtype: float64

# %% [markdown]
# ##### What is the max close price for each company's stock throughout the time period?

# %%
# your code 
max_cost=prices['Close'].max()
print(max_cost)
# Out:
# Ticker
# AMZN    154.070007
# MSFT    377.783569
# META    356.124573
# GOOG    141.849304
# AAPL    196.446838
# dtype: float64

# %% [markdown]
# ##### Create a new dataframe called returns. This dataframe will contain the returns for each company's stock. returns are typically defined by:
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %% [markdown]
# ##### We can use pandas pct_change() method on the Close column to create a new dataframe representing this return value. Use .groupby().

# %%
returns = pd.DataFrame(prices.groupby("Company")["Close"].pct_change())
print(returns)
# Out:
# Price      Close
# Ticker      AMZN      MSFT      META      GOOG      AAPL
# 0            NaN       NaN       NaN       NaN       NaN
# 1      -0.007924 -0.043743  0.021084 -0.011037  0.010314
# 2      -0.023726 -0.029638 -0.003376 -0.021869 -0.010605
# 3       0.035611  0.011785  0.024263  0.016019  0.036794
# 4       0.014870  0.009736 -0.004230  0.007260  0.004089
# ..           ...       ...       ...       ...       ...
# 245    -0.002730  0.002784 -0.001977  0.006488 -0.005548
# 246    -0.000065  0.000214  0.004075  0.000701 -0.002841
# 247    -0.000456 -0.001575  0.008455 -0.009663  0.000518
# 248     0.000261  0.003235  0.001369 -0.001131  0.002226
# 249    -0.009388  0.002025 -0.012168 -0.002477 -0.005424
#
# [250 rows x 5 columns]

# %% [markdown]
# ##### Using this returns dataframe, figure out on what dates each company stock had the best and worst single day returns. Did anything significant happen that day?

# %%
best = returns.idxmax()
worst = returns.idxmin()
print(best)
print(worst)
# Out:
# Price  Ticker
# Close  AMZN      147
#        MSFT       78
#        META       21
#        GOOG       21
#        AAPL       85
# dtype: int64
# Price  Ticker
# Close  AMZN       22
#        MSFT        1
#        META       51
#        GOOG      204
#        AAPL      147
# dtype: int64

# %% [markdown]
# ##### Please state here what you have noticed. Did anything significant happen in that time frame?

# %%
#testing commit

# %% [markdown]
# ##### Take a look at the standard deviation of the returns, which stock would you classify as the riskiest over the entire time period?

# %%
#  your code here
print(returns.std())
# Out:
# Price  Ticker
# Close  AMZN      0.020805
#        MSFT      0.015824
#        META      0.025090
#        GOOG      0.019283
#        AAPL      0.012570
# dtype: float64

# %% [markdown]
# ##### Which company would you classify as the riskiest for each year?

# %%
# your code here

# %% [markdown]
# ##### Moving Averages
#
# ##### Please derive the moving averages for these stocks in the year 2022. Use .rolling() in pandas to get the rolling average calculation.

# %%
# your code here
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File c:\Users\Tuong\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\window\rolling.py:489, in BaseWindow._apply_columnwise(self, homogeneous_func, name, numeric_only)
#     488 try:
# --> 489     arr = self._prep_values(arr)
#     490 except (TypeError, NotImplementedError) as err:
#
# File c:\Users\Tuong\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\window\rolling.py:361, in BaseWindow._prep_values(self, values)
#     360 if needs_i8_conversion(values.dtype):
# --> 361     raise NotImplementedError(
#     362         f"ops for {type(self).__name__} for this "
#     363         f"dtype {values.dtype} are not implemented"
#     364     )
#     365 # GH #12373 : rolling functions error on float32 data
#     366 # make sure the data is coerced to float64
#
# NotImplementedError: ops for Rolling for this dtype datetime64[ns] are not implemented
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 # your code here
# ----> 2 print(prices.rolling(window=7).mean())
#
# File c:\Users\Tuong\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\window\rolling.py:2259, in Rolling.mean(self, numeric_only, engine, engine_kwargs)
#    2216 @doc(
#    2217     template_header,
#    2218     create_section_header("Parameters"),
#    (...)   2257     engine_kwargs: dict[str, bool] | None = None,
#    2258 ):
# -> 2259     return super().mean(
#    2260         numeric_only=numeric_only,
#    2261         engine=engine,
#    2262         engine_kwargs=engine_kwargs,
#    2263     )
#
# File c:\Users\Tuong\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\window\rolling.py:1625, in RollingAndExpandingMixin.mean(self, numeric_only, engine, engine_kwargs)
#    1623         return self._numba_apply(sliding_mean, engine_kwargs)
#    1624 window_func = window_aggregations.roll_mean
# -> 1625 return self._apply(window_func, name="mean", numeric_only=numeric_only)
#
# File c:\Users\Tuong\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\window\rolling.py:619, in BaseWindow._apply(self, func, name, numeric_only, numba_args, **kwargs)
#     616     return result
#     618 if self.method == "single":
# --> 619     return self._apply_columnwise(homogeneous_func, name, numeric_only)
#     620 else:
#     621     return self._apply_tablewise(homogeneous_func, name, numeric_only)
#
# File c:\Users\Tuong\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\window\rolling.py:491, in BaseWindow._apply_columnwise(self, homogeneous_func, name, numeric_only)
#     489     arr = self._prep_values(arr)
#     490 except (TypeError, NotImplementedError) as err:
# --> 491     raise DataError(
#     492         f"Cannot aggregate non-numeric type: {arr.dtype}"
#     493     ) from err
#     494 res = homogeneous_func(arr)
#     495 res_values.append(res)
#
# DataError: Cannot aggregate non-numeric type: datetime64[ns]

# %% [markdown]
# ### Bonus Question (Choose one out of these two):
# ##### 1. Among all publicly traded companies in the technology industry, identify which company has performed the best this year so far (up until today). To answer this question, you need to download the latest stock price data from sources like Yahoo Finance API.
#
#
# * Use your creativity in this question to examine perhaps whether small cap vs. mid cap vs. large cap tech firms did better, or whether tech firms in a specific subindustry (e.g. hardware, semiconductor) did better.
#
# * To expand your analysis to a broader set of technology firms, you may find a list of tech firms here: https://mergr.com/public-information-technology-companies
# You could also use some other lists of public tech firms.
#
# ##### 2. Among all publicly traded U.S. companies the airline industry, find out which company has performed the best this year so far (up until today). To answer this question, you need to download the latest stock price data from sources like Yahoo Finance API.

# %%
# your code here

# %% [markdown]
# # Great Job!
